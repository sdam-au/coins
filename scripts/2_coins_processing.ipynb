# %%
import sddk
import pandas as pd

# %%
try:
    coins = pd.read_json("../data/coins_raw_df.json")
except:
    s = sddk.cloudSession("sciencedata.dk", "SDAM_root/SDAM_data/coins", "648597@au.dk")
    coins = s.read_file("coins_df.json")
    coins.to_json("../data/coins_raw_df.json")

# %%
len(coins)
# Out:
# 51311

# %%
coins[coins["ontology#hasEndDate"].str.contains("-0004")]
# Out:
#                                                    @id  \
# 56     http://numismatics.org/ocre/id/ric.1(2).aug.466
# 74     http://numismatics.org/ocre/id/ric.1(2).aug.300
# 397    http://numismatics.org/ocre/id/ric.1(2).aug.318
# 1012   http://numismatics.org/ocre/id/ric.1(2).aug.299
# 1836   http://numismatics.org/ocre/id/ric.1(2).aug.322
# 4097   http://numismatics.org/ocre/id/ric.1(2).aug.279
# 6158   http://numismatics.org/ocre/id/ric.1(2).aug.310
# 6748   http://numismatics.org/ocre/id/ric.1(2).aug.465
# 6755   http://numismatics.org/ocre/id/ric.1(2).aug.287
# 7232   http://numismatics.org/ocre/id/ric.1(2).aug.308
# 8100   http://numismatics.org/ocre/id/ric.1(2).aug.281
# 8900   http://numismatics.org/ocre/id/ric.1(2).aug.295
# 9848   http://numismatics.org/ocre/id/ric.1(2).aug.316
# 10547  http://numismatics.org/ocre/id/ric.1(2).aug.284
# 16250  http://numismatics.org/ocre/id/ric.1(2).aug.306
# 18931  http://numismatics.org/ocre/id/ric.1(2).aug.304
# 19571  http://numismatics.org/ocre/id/ric.1(2).aug.315
# 20327  http://numismatics.org/ocre/id/ric.1(2).aug.292
# 21068  http://numismatics.org/ocre/id/ric.1(2).aug.468
# 21194  http://numismatics.org/ocre/id/ric.1(2).aug.305
# 21357  http://numismatics.org/ocre/id/ric.1(2).aug.312
# 22710  http://numismatics.org/ocre/id/ric.1(2).aug.303
# 23091  http://numismatics.org/ocre/id/ric.1(2).aug.317
# 23293  http://numismatics.org/ocre/id/ric.1(2).aug.297
# 24573  http://numismatics.org/ocre/id/ric.1(2).aug.319
# 25568  http://numismatics.org/ocre/id/ric.1(2).aug.313
# 25834  http://numismatics.org/ocre/id/ric.1(2).aug.285
# 26040  http://numismatics.org/ocre/id/ric.1(2).aug.320
# 26829  http://numismatics.org/ocre/id/ric.1(2).aug.290
# 28189  http://numismatics.org/ocre/id/ric.1(2).aug.278
# 28676  http://numismatics.org/ocre/id/ric.1(2).aug.311
# 33376  http://numismatics.org/ocre/id/ric.1(2).aug.302
# 34066  http://numismatics.org/ocre/id/ric.1(2).aug.321
# 34442  http://numismatics.org/ocre/id/ric.1(2).aug.309
# 34804  http://numismatics.org/ocre/id/ric.1(2).aug.294
# 37196  http://numismatics.org/ocre/id/ric.1(2).aug.286
# 39094  http://numismatics.org/ocre/id/ric.1(2).aug.467
# 42097  http://numismatics.org/ocre/id/ric.1(2).aug.293
# 43057  http://numismatics.org/ocre/id/ric.1(2).aug.314
# 43432  http://numismatics.org/ocre/id/ric.1(2).aug.289
# 45895  http://numismatics.org/ocre/id/ric.1(2).aug.307
# 46224  http://numismatics.org/ocre/id/ric.1(2).aug.288
# 48625  http://numismatics.org/ocre/id/ric.1(2).aug.301
# 48650  http://numismatics.org/ocre/id/ric.1(2).aug.291
# 48833  http://numismatics.org/ocre/id/ric.1(2).aug.280
# 49314  http://numismatics.org/ocre/id/ric.1(2).aug.298
# 49342  http://numismatics.org/ocre/id/ric.1(2).aug.283
# 49971  http://numismatics.org/ocre/id/ric.1(2).aug.282
# 50865  http://numismatics.org/ocre/id/ric.1(2).aug.296
#
#                                                    @type  \
# 56     [http://nomisma.org/ontology#TypeSeriesItem, h...
# 74     [http://nomisma.org/ontology#TypeSeriesItem, h...
# 397    [http://nomisma.org/ontology#TypeSeriesItem, h...
# 1012   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 1836   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 4097   [http://www.w3.org/2004/02/skos/core#Concept, ...
# 6158   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 6748   [http://www.w3.org/2004/02/skos/core#Concept, ...
# 6755   [http://www.w3.org/2004/02/skos/core#Concept, ...
# 7232   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 8100   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 8900   [http://www.w3.org/2004/02/skos/core#Concept, ...
# 9848   [http://nomisma.org/ontology#TypeSeriesItem, h...
# 10547  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 16250  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 18931  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 19571  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 20327  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 21068  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 21194  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 21357  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 22710  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 23091  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 23293  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 24573  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 25568  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 25834  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 26040  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 26829  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 28189  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 28676  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 33376  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 34066  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 34442  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 34804  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 37196  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 39094  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 42097  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 43057  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 43432  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 45895  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 46224  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 48625  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 48650  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 48833  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 49314  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 49342  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 49971  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 50865  [http://nomisma.org/ontology#TypeSeriesItem, h...
#
#       ontology#hasAuthority ontology#hasDenomination ontology#hasEndDate  \
# 56                 augustus                 quadrans               -0004
# 74                 augustus                 denarius               -0004
# 397                augustus                 denarius               -0004
# 1012               augustus                 denarius               -0004
# 1836               augustus                 denarius               -0004
# 4097               augustus                   aureus               -0004
# 6158               augustus                 denarius               -0004
# 6748               augustus                 quadrans               -0004
# 6755               augustus                 denarius               -0004
# 7232               augustus                   aureus               -0004
# 8100               augustus                 denarius               -0004
# 8900               augustus                 denarius               -0004
# 9848               augustus                   aureus               -0004
# 10547              augustus                 denarius               -0004
# 16250              augustus                 denarius               -0004
# 18931              augustus                 denarius               -0004
# 19571              augustus                 denarius               -0004
# 20327              augustus                 denarius               -0004
# 21068              augustus                 quadrans               -0004
# 21194              augustus                 denarius               -0004
# 21357              augustus                   aureus               -0004
# 22710              augustus                 denarius               -0004
# 23091              augustus                 denarius               -0004
# 23293              augustus                 denarius               -0004
# 24573              augustus                 denarius               -0004
# 25568              augustus                 denarius               -0004
# 25834              augustus                   aureus               -0004
# 26040              augustus                 denarius               -0004
# 26829              augustus                 denarius               -0004
# 28189              augustus                   aureus               -0004
# 28676              augustus                 denarius               -0004
# 33376              augustus                   aureus               -0004
# 34066              augustus                   aureus               -0004
# 34442              augustus                 denarius               -0004
# 34804              augustus                 denarius               -0004
# 37196              augustus                   aureus               -0004
# 39094              augustus                 quadrans               -0004
# 42097              augustus                   aureus               -0004
# 43057              augustus                 denarius               -0004
# 43432              augustus                 denarius               -0004
# 45895              augustus                 denarius               -0004
# 46224              augustus                 denarius               -0004
# 48625              augustus                 denarius               -0004
# 48650              augustus                 denarius               -0004
# 48833              augustus                 denarius               -0004
# 49314              augustus                   aureus               -0004
# 49342              augustus                 denarius               -0004
# 49971              augustus                 denarius               -0004
# 50865              augustus                 denarius               -0004
#
#       ontology#hasManufacture ontology#hasMaterial ontology#hasMint  \
# 56                     struck                   ae             rome
# 74                     struck                   ar             rome
# 397                    struck                   ar             rome
# 1012                   struck                   ar             rome
# 1836                   struck                   ar             rome
# 4097                   struck                   av             rome
# 6158                   struck                   ar             rome
# 6748                   struck                   ae             rome
# 6755                   struck                   ar             rome
# 7232                   struck                   av             rome
# 8100                   struck                   ar             rome
# 8900                   struck                   ar             rome
# 9848                   struck                   av             rome
# 10547                  struck                   ar             rome
# 16250                  struck                   ar             rome
# 18931                  struck                   ar             rome
# 19571                  struck                   ar             rome
# 20327                  struck                   ar             rome
# 21068                  struck                   ae             rome
# 21194                  struck                   ar             rome
# 21357                  struck                   av             rome
# 22710                  struck                   ar             rome
# 23091                  struck                   ar             rome
# 23293                  struck                   ar             rome
# 24573                  struck                   ar             rome
# 25568                  struck                   ar             rome
# 25834                  struck                   av             rome
# 26040                  struck                   ar             rome
# 26829                  struck                   ar             rome
# 28189                  struck                   av             rome
# 28676                  struck                   ar             rome
# 33376                  struck                   av             rome
# 34066                  struck                   av             rome
# 34442                  struck                   ar             rome
# 34804                  struck                   ar             rome
# 37196                  struck                   av             rome
# 39094                  struck                   ae             rome
# 42097                  struck                   av             rome
# 43057                  struck                   ar             rome
# 43432                  struck                   ar             rome
# 45895                  struck                   ar             rome
# 46224                  struck                   ar             rome
# 48625                  struck                   ar             rome
# 48650                  struck                   ar             rome
# 48833                  struck                   ar             rome
# 49314                  struck                   av             rome
# 49342                  struck                   ar             rome
# 49971                  struck                   ar             rome
# 50865                  struck                   ar             rome
#
#                     @id_obverse ontology#hasRegion  ... isReplacedBy  \
# 56     ric.1(2).aug.466#obverse              italy  ...
# 74     ric.1(2).aug.300#obverse              italy  ...
# 397    ric.1(2).aug.318#obverse              italy  ...
# 1012   ric.1(2).aug.299#obverse              italy  ...
# 1836   ric.1(2).aug.322#obverse              italy  ...
# 4097   ric.1(2).aug.279#obverse              italy  ...
# 6158   ric.1(2).aug.310#obverse              italy  ...
# 6748   ric.1(2).aug.465#obverse              italy  ...
# 6755   ric.1(2).aug.287#obverse              italy  ...
# 7232   ric.1(2).aug.308#obverse              italy  ...
# 8100   ric.1(2).aug.281#obverse              italy  ...
# 8900   ric.1(2).aug.295#obverse              italy  ...
# 9848   ric.1(2).aug.316#obverse              italy  ...
# 10547  ric.1(2).aug.284#obverse              italy  ...
# 16250  ric.1(2).aug.306#obverse              italy  ...
# 18931  ric.1(2).aug.304#obverse              italy  ...
# 19571  ric.1(2).aug.315#obverse              italy  ...
# 20327  ric.1(2).aug.292#obverse              italy  ...
# 21068  ric.1(2).aug.468#obverse              italy  ...
# 21194  ric.1(2).aug.305#obverse              italy  ...
# 21357  ric.1(2).aug.312#obverse              italy  ...
# 22710  ric.1(2).aug.303#obverse              italy  ...
# 23091  ric.1(2).aug.317#obverse              italy  ...
# 23293  ric.1(2).aug.297#obverse              italy  ...
# 24573  ric.1(2).aug.319#obverse              italy  ...
# 25568  ric.1(2).aug.313#obverse              italy  ...
# 25834  ric.1(2).aug.285#obverse              italy  ...
# 26040  ric.1(2).aug.320#obverse              italy  ...
# 26829  ric.1(2).aug.290#obverse              italy  ...
# 28189  ric.1(2).aug.278#obverse              italy  ...
# 28676  ric.1(2).aug.311#obverse              italy  ...
# 33376  ric.1(2).aug.302#obverse              italy  ...
# 34066  ric.1(2).aug.321#obverse              italy  ...
# 34442  ric.1(2).aug.309#obverse              italy  ...
# 34804  ric.1(2).aug.294#obverse              italy  ...
# 37196  ric.1(2).aug.286#obverse              italy  ...
# 39094  ric.1(2).aug.467#obverse              italy  ...
# 42097  ric.1(2).aug.293#obverse              italy  ...
# 43057  ric.1(2).aug.314#obverse              italy  ...
# 43432  ric.1(2).aug.289#obverse              italy  ...
# 45895  ric.1(2).aug.307#obverse              italy  ...
# 46224  ric.1(2).aug.288#obverse              italy  ...
# 48625  ric.1(2).aug.301#obverse              italy  ...
# 48650  ric.1(2).aug.291#obverse              italy  ...
# 48833  ric.1(2).aug.280#obverse              italy  ...
# 49314  ric.1(2).aug.298#obverse              italy  ...
# 49342  ric.1(2).aug.283#obverse              italy  ...
# 49971  ric.1(2).aug.282#obverse              italy  ...
# 50865  ric.1(2).aug.296#obverse              italy  ...
#
#       core#exactMatch       ontology#hasIssuer  \
# 56                           c_naevius_capella
# 74                     p_petronius_turpilianus
# 397                                  m_durmius
# 1012                   p_petronius_turpilianus
# 1836                                 q_rustius
# 4097                   p_petronius_turpilianus
# 6158                        l_aquillius_florus
# 6748                       p_betilienus_bassus
# 6755                   p_petronius_turpilianus
# 7232                        l_aquillius_florus
# 8100                   p_petronius_turpilianus
# 8900                   p_petronius_turpilianus
# 9848                                 m_durmius
# 10547                  p_petronius_turpilianus
# 16250                       l_aquillius_florus
# 18931                       l_aquillius_florus
# 19571                                m_durmius
# 20327                  p_petronius_turpilianus
# 21068                      l_valerius_catullus
# 21194                       l_aquillius_florus
# 21357                                m_durmius
# 22710                       l_aquillius_florus
# 23091                                m_durmius
# 23293                  p_petronius_turpilianus
# 24573                                m_durmius
# 25568                                m_durmius
# 25834                  p_petronius_turpilianus
# 26040                                m_durmius
# 26829                  p_petronius_turpilianus
# 28189                  p_petronius_turpilianus
# 28676                                m_durmius
# 33376                       l_aquillius_florus
# 34066                                q_rustius
# 34442                       l_aquillius_florus
# 34804                  p_petronius_turpilianus
# 37196                  p_petronius_turpilianus
# 39094                      c_rubellius_blandus
# 42097                  p_petronius_turpilianus
# 43057                                m_durmius
# 43432                  p_petronius_turpilianus
# 45895                       l_aquillius_florus
# 46224                  p_petronius_turpilianus
# 48625                       l_aquillius_florus
# 48650                  p_petronius_turpilianus
# 48833                  p_petronius_turpilianus
# 49314                  p_petronius_turpilianus
# 49342                  p_petronius_turpilianus
# 49971                  p_petronius_turpilianus
# 50865                  p_petronius_turpilianus
#
#                              ontology#hasLegend_obverse  \
# 56                                    C NAEVIVS CAPELLA
# 74                                      CAESAR AVGVSTVS
# 397                                     CAESAR AVGVSTVS
# 1012                                    CAESAR AVGVSTVS
# 1836                          Q RVSTIVS FORTVNAE ANTIAT
# 4097   TVRPILIANVS IIIVIR FERON|TVRPILIANVS IIIVIR FERO
# 6158                                    CAESAR AVGVSTVS
# 6748                                P BETILIENVS BASSVS
# 6755                                 TVRPILIANVS IIIVIR
# 7232                                    CAESAR AVGVSTVS
# 8100   TVRPILIANVS IIIVIR FERO|TVRPILIANVS IIIVIR FERON
# 8900                                    CAESAR AVGVSTVS
# 9848                                    CAESAR AVGVSTVS
# 10547                    P PETRON TVRPILIAN IIIVIR FERO
# 16250                         L AQVILLIVS FLORVS IIIVIR
# 18931                         L AQVILLIVS FLORVS IIIVIR
# 19571                           M DVRMIVS IIIVIR HONORI
# 20327                         P PETRON TVRPILIAN IIIVIR
# 21068                               L VALERIVS CATVLLVS
# 21194                         L AQVILLIVS FLORVS IIIVIR
# 21357                           M DVRMIVS IIIVIR HONORI
# 22710                         L AQVILLIVS FLORVS IIIVIR
# 23091                                   CAESAR AVGVSTVS
# 23293                                   CAESAR AVGVSTVS
# 24573                                   CAESAR AVGVSTVS
# 25568                          M DVRMIVS III VIR HONORI
# 25834  TVRPILIANVS IIIVIR FERO|TVRPILIANVS IIIVIR FERON
# 26040                                   CAESAR AVGVSTVS
# 26829                        P PETRON TVRPILIAN III VIR
# 28189                                TVRPILIANVS IIIVIR
# 28676                           M DVRMIVS IIIVIR HONORI
# 33376                         L AQVILLIVS FLORVS IIIVIR
# 34066                                Q RVSTIVS FORTVNAE
# 34442                                   CAESAR AVGVSTVS
# 34804                                   CAESAR AVGVSTVS
# 37196  TVRPILIANVS IIIVIR FERO|TVRPILIANVS IIIVIR FERON
# 39094                               C RVBELLIVS BLANDVS
# 42097                                   CAESAR AVGVSTVS
# 43057                           M DVRMIVS IIIVIR HONORI
# 43432                    P PETRON TVRPILIAN IIIVIR FERO
# 45895                         L AQVILLIVS FLORVS IIIVIR
# 46224  TVRPILIANVS IIIVIR FERON|TVRPILIANVS IIIVIR FERO
# 48625                         L AQVILLIVS FLORVS IIIVIR
# 48650  TVRPILIANVS IIIVIR FERO|TVRPILIANVS IIIVIR FERON
# 48833  TVRPILIANVS IIIVIR FERON|TVRPILIANVS IIIVIR FERO
# 49314                                   CAESAR AVGVSTVS
# 49342                         P PETRON TVRPILIAN IIIVIR
# 49971                         P PETRON TVRPILIAN IIIVIR
# 50865                                   CAESAR AVGVSTVS
#
#       ontology#hasPortrait_obverse  \
# 56
# 74                        augustus
# 397                       augustus
# 1012                      augustus
# 1836                         58260
# 4097                         58248
# 6158                      augustus
# 6748
# 6755                        175498
# 7232                      augustus
# 8100                         58248
# 8900                      augustus
# 9848                      augustus
# 10547                        58248
# 16250                        80685
# 18931                        58616
# 19571                        92677
# 20327                       175498
# 21068
# 21194                        80685
# 21357                        92677
# 22710                        58616
# 23091                     augustus
# 23293                     augustus
# 24573                     augustus
# 25568                        92677
# 25834                       175498
# 26040                     augustus
# 26829                       175498
# 28189                       175498
# 28676                        92677
# 33376                        59294
# 34066                        58260
# 34442                     augustus
# 34804                     augustus
# 37196                        58248
# 39094
# 42097                     augustus
# 43057                        58628
# 43432                        58248
# 45895                        80685
# 46224                        58248
# 48625                        80685
# 48650                        58248
# 48833                        58248
# 49314                     augustus
# 49342                       175498
# 49971                       175498
# 50865                     augustus
#
#                                      description_obverse  \
# 56                                Legend surrounding S C
# 74                         Head of Augustus, bare, right
# 397                        Head of Augustus, bare, right
# 1012                       Head of Augustus, bare, right
# 1836   Jugate busts of Fortuna Victrix, with round he...
# 4097            Bust of Feronia, diademed, draped, right
# 6158                       Head of Augustus, bare, right
# 6748                              Legend surrounding S C
# 6755                  Head of Liber, ivy-wreathed, right
# 7232               Head of Augustus, oak-wreathed, right
# 8100            Bust of Feronia, diademed, draped, right
# 8900                       Head of Augustus, bare, right
# 9848               Head of Augustus, oak-wreathed, right
# 10547           Bust of Feronia, diademed, draped, right
# 16250  Bust of Virtus, draped, right, with feathered ...
# 18931                        Head of Sol, radiate, right
# 19571  Head of Honos, right, in between two six-rayed...
# 20327                 Head of Liber, ivy-wreathed, right
# 21068                             Legend surrounding S C
# 21194  Bust of Virtus, draped, right, with feathered ...
# 21357  Head of Honos, right, in between two six-rayed...
# 22710                        Head of Sol, radiate, right
# 23091                      Head of Augustus, bare, right
# 23293                      Head of Augustus, bare, right
# 24573                      Head of Augustus, bare, right
# 25568  Head of Honos, right, in between two six-rayed...
# 25834                 Head of Liber, ivy-wreathed, right
# 26040                      Head of Augustus, bare, right
# 26829                 Head of Liber, ivy-wreathed, right
# 28189                 Head of Liber, ivy-wreathed, right
# 28676  Head of Honos, right, in between two six-rayed...
# 33376         Triskelis with winged Medusa head and legs
# 34066  Confronting busts of Fortuna Victrix, with rou...
# 34442                      Head of Augustus, bare, right
# 34804                      Head of Augustus, bare, right
# 37196           Bust of Feronia, diademed, draped, right
# 39094                             Legend surrounding S C
# 42097              Head of Augustus, oak-wreathed, right
# 43057  Bust of Young Hercules, diademed, right, with ...
# 43432           Bust of Feronia, diademed, draped, right
# 45895  Bust of Virtus, draped, right, with feathered ...
# 46224           Bust of Feronia, diademed, draped, right
# 48625            Bust of Virtus, helmeted, draped, right
# 48650           Bust of Feronia, diademed, draped, right
# 48833           Bust of Feronia, diademed, draped, right
# 49314              Head of Augustus, oak-wreathed, right
# 49342                 Head of Liber, ivy-wreathed, right
# 49971                 Head of Liber, ivy-wreathed, right
# 50865                      Head of Augustus, bare, right
#
#              ontology#hasLegend_reverse ontology#hasPortrait_reverse  \
# 56                     IIIVIR A A A F F
# 74                   TVRPILIANVS IIIVIR
# 397                    M DVRMIVS IIIVIR
# 1012                 TVRPILIANVS IIIVIR                  nomisma.rdf
# 1836              CAESARI AVGVSTO EX SC
# 4097                     AVGVSTO OB C S
# 6158   L AQVILLIVS FLORVS III VIR SICIL
# 6748                   IIIVIR A A A F F
# 6755          CAESAR AVGVSTVS SIGN RECE
# 7232          L AQVILLIVS FLORVS IIIVIR
# 8100                    AVGVSTVS CAESAR                     augustus
# 8900          P PETRON TVRPILIAN IIIVIR
# 9848                   M DVRMIVS IIIVIR
# 10547                   AVGVSTVS CAESAR                     augustus
# 16250           CAESAR DIVI F ARME CAPT
# 18931         CAESAR AVGVSTVS SIGN RECE
# 19571         CAESAR AVGVSTVS SIGN RECE
# 20327           CAESAR DIVI F ARME CAPT
# 21068                  IIIVIR A A A F F
# 21194         CAESAR AVGVSTVS SIGN RECE
# 21357                    AVGVSTO OB C S
# 22710               CAESAR AVGVSTVS S C
# 23091                  M DVRMIVS IIIVIR
# 23293        P PETRON TVRPILIAN III VIR
# 24573                  M DVRMIVS IIIVIR                        60915
# 25568               CAESAR AVGVSTVS S C
# 25834                   CAESAR AVGVSTVS
# 26040                  M DVRMIVS IIIVIR                        60915
# 26829           CAESAR DIVI F ARME CAPT
# 28189                    AVGVSTO OB C S
# 28676                   AVGVSTVS CAESAR                     augustus
# 33376                   CAESAR AVGVSTVS
# 34066                   CAESARI AVGVSTO                        60915
# 34442        L AQVILLIVS FLORVS III VIR
# 34804         P PETRON TVRPILIAN IIIVIR                        59726
# 37196                   CAESAR AVGVSTVS
# 39094                  IIIVIR A A A F F
# 42097         P PETRON TVRPILIAN IIIVIR
# 43057         CAESAR AVGVSTVS SIGN RECE
# 43432         CAESAR AVGVSTVS SIGN RECE
# 45895       CAESAR DIVI F ARMINIA CAPTA
# 46224         CAESAR AVGVSTVS SIGN RECE
# 48625                   AVGVSTVS CAESAR                     augustus
# 48650           CAESAR DIVI F ARME CAPT
# 48833                   AVGVSTVS CAESAR                     augustus
# 49314                TVRPILIANVS IIIVIR
# 49342                   AVGVSTVS CAESAR                     augustus
# 49971                   AVGVSTVS CAESAR                     augustus
# 50865        P PETRON TVRPILIAN III VIR
#
#                                      description_reverse  \
# 56         Altar with bowl-shaped top, hung with garland
# 74                        Crescent; six-rayed star above
# 397                                  Lion attacking stag
# 1012   Tarpeia facing with hands raised, half buried ...
# 1836                   Ornamented altar inscribed FOR RE
# 4097                   Legend in two lines in oak-wreath
# 6158   Warrior in military dress standing, left, carr...
# 6748       Altar with bowl-shaped top, hung with garland
# 6755   Parthian kneeling right, extending standard wi...
# 7232                         Open flower with six petals
# 8100   Augustus standing in biga of elephants, left, ...
# 8900   Young satyr seated right on ground resting chi...
# 9848                              Crab holding butterfly
# 10547  Augustus standing in biga of elephants, left, ...
# 16250      Armenian kneeling right, extending both hands
# 18931  Parthian kneeling right, with standard and vex...
# 19571  Parthian kneeling right, extending standard wi...
# 20327  Armenian, wearing tiara and robe, kneeling rig...
# 21068      Altar with bowl-shaped top, hung with garland
# 21194  Parthian kneeling right, with standard and vex...
# 21357                  Legend in two lines in oak-wreath
# 22710  Slow quadriga right, with round basket-like ca...
# 23091             Boar standing, right, pierced by spear
# 23293                              Pegasus walking right
# 24573  Bull, manfaced, walking right, crowned by Vict...
# 25568  Slow quadriga right, with round basket-like ca...
# 25834  Legend above and below two laurel branches fla...
# 26040  Victory advancing right, holding wreath in rig...
# 26829  Armenian, wearing tiara and robe, kneeling rig...
# 28189                  Legend in two lines in oak-wreath
# 28676  Augustus standing in biga of elephants, left, ...
# 33376  Two laurel branches flanking oak-wreath; insid...
# 34066  Victory tilted left, placing on cippus a shiel...
# 34442                        Open flower with six petals
# 34804  Pan standing left, holding syrinx in right han...
# 37196  Legend above and below two laurel branches fla...
# 39094      Altar with bowl-shaped top, hung with garland
# 42097                                Tortoise-shell lyre
# 43057  Parthian kneeling right, extending standard wi...
# 43432  Parthian kneeling right, extending standard wi...
# 45895  Armenian standing, facing, wearing tiara and c...
# 46224  Parthian kneeling right, extending standard wi...
# 48625  Augustus standing in biga of elephants, left, ...
# 48650  Armenian, wearing tiara and robe, kneeling rig...
# 48833  Augustus standing in biga of elephants, left, ...
# 49314                                Tortoise-shell lyre
# 49342  Augustus standing in biga of elephants, left, ...
# 49971  Augustus standing in biga of elephants, left, ...
# 50865  Siren with wings, standing left, holding flute...
#
#       ontology#hasControlmark_reverse
# 56                               None
# 74                               None
# 397                              None
# 1012                             None
# 1836                             None
# 4097                             None
# 6158                             None
# 6748                             None
# 6755                             None
# 7232                             None
# 8100                             None
# 8900                             None
# 9848                             None
# 10547                            None
# 16250                            None
# 18931                            None
# 19571                            None
# 20327                            None
# 21068                            None
# 21194                            None
# 21357                            None
# 22710                            None
# 23091                            None
# 23293                            None
# 24573                            None
# 25568                            None
# 25834                            None
# 26040                            None
# 26829                            None
# 28189                            None
# 28676                            None
# 33376                            None
# 34066                            None
# 34442                            None
# 34804                            None
# 37196                            None
# 39094                            None
# 42097                            None
# 43057                            None
# 43432                            None
# 45895                            None
# 46224                            None
# 48625                            None
# 48650                            None
# 48833                            None
# 49314                            None
# 49342                            None
# 49971                            None
# 50865                            None
#
# [49 rows x 29 columns]

# %%
def clean_date(datetime_string):
    date = None
    if len(datetime_string) >=10:
        date = datetime_string.partition("-")[0]
    else:
        date = datetime_string
    if date[:2] in ["19", "20"]:
        date = "00" + date[2:]
    try:
        date = int(date)
    except:
        date = None
    return date
coins["not_before"] = coins["ontology#hasStartDate"].apply(clean_date)
coins["not_after"] = coins["ontology#hasEndDate"].apply(clean_date)

# %%
coins.head(20)
# Out:
#                                                   @id  \
# 0        http://numismatics.org/ocre/id/ric.6.sis.221
# 1       http://numismatics.org/ocre/id/ric.4.ph_i.28A
# 2      http://numismatics.org/ocre/id/ric.9.tri.96B.2
# 3           http://numismatics.org/ocre/id/ric.8.aq.3
# 4        http://numismatics.org/ocre/id/ric.4.crl.191
# 5           http://numismatics.org/ocre/id/ric.7.ar.2
# 6   http://numismatics.org/ocre/id/ric.2_1(2).tit.288
# 7       http://numismatics.org/ocre/id/ric.5.cara.745
# 8       http://numismatics.org/ocre/id/ric.6.anch.128
# 9         http://numismatics.org/ocre/id/ric.5.aur.45
# 10       http://numismatics.org/ocre/id/ric.9.cnp.57B
# 11       http://numismatics.org/ocre/id/ric.4.pert.1A
# 12       http://numismatics.org/ocre/id/ric.7.rom.352
# 13        http://numismatics.org/ocre/id/ric.5.pro.29
# 14      http://numismatics.org/ocre/id/ric.9.aq.7A.xb
# 15  http://numismatics.org/ocre/id/ric.2_3(2).hdn....
# 16       http://numismatics.org/ocre/id/ric.7.tri.205
# 17    http://numismatics.org/ocre/id/ric.3.m_aur.1397
# 18  http://numismatics.org/ocre/id/ric.2.tr.730_de...
# 19       http://numismatics.org/ocre/id/ric.7.tri.175
#
#                                                 @type ontology#hasAuthority  \
# 0   [http://www.w3.org/2004/02/skos/core#Concept, ...              licinius
# 1   [http://www.w3.org/2004/02/skos/core#Concept, ...       philip_the_arab
# 2   [http://nomisma.org/ontology#TypeSeriesItem, h...        valentinian_ii
# 3   [http://www.w3.org/2004/02/skos/core#Concept, ...        constantine_ii
# 4   [http://www.w3.org/2004/02/skos/core#Concept, ...             caracalla
# 5   [http://nomisma.org/ontology#TypeSeriesItem, h...         constantine_i
# 6   [http://nomisma.org/ontology#TypeSeriesItem, h...                 titus
# 7   [http://nomisma.org/ontology#TypeSeriesItem, h...             carausius
# 8   [http://nomisma.org/ontology#TypeSeriesItem, h...        maximinus_daia
# 9   [http://nomisma.org/ontology#TypeSeriesItem, h...              aurelian
# 10  [http://www.w3.org/2004/02/skos/core#Concept, ...          theodosius_i
# 11  [http://nomisma.org/ontology#TypeSeriesItem, h...              pertinax
# 12  [http://www.w3.org/2004/02/skos/core#Concept, ...         constantine_i
# 13  [http://www.w3.org/2004/02/skos/core#Concept, ...                probus
# 14  [http://nomisma.org/ontology#TypeSeriesItem, h...         valentinian_i
# 15  [http://www.w3.org/2004/02/skos/core#Concept, ...               hadrian
# 16  [http://www.w3.org/2004/02/skos/core#Concept, ...         constantine_i
# 17  [http://nomisma.org/ontology#TypeSeriesItem, h...       marcus_aurelius
# 18  [http://nomisma.org/ontology#TypeSeriesItem, h...                trajan
# 19  [http://www.w3.org/2004/02/skos/core#Concept, ...         constantine_i
#
#                ontology#hasDenomination ontology#hasEndDate  \
# 0                                   ae2          0311-01-01
# 1                                aureus          0247-01-01
# 2                                   ae3          0392-01-01
# 3                         multiple-gold          0340-01-01
# 4                              denarius          0211-01-01
# 5                               solidus          0313-01-01
# 6                            sestertius          0081-01-01
# 7                          antoninianus          0293-01-01
# 8                                aureus          0311-01-01
# 9                          antoninianus          0275-01-01
# 10                                  ae3          0383-01-01
# 11                                               0193-01-01
# 12  _:N98913416d8d84561b5eb117ba9afd288          0335-01-01
# 13                         antoninianus          0282-01-01
# 14                                  ae3          0367-01-01
# 15                            dupondius          0137-01-01
# 16  _:N53c1dc41cd28416da12e2041ae1f5aa3          0318-01-01
# 17                           sestertius          0164-01-01
# 18                             denarius          0117-01-01
# 19  _:N3365400e906645dfa08e899dad9c41f9          0318-01-01
#
#    ontology#hasManufacture ontology#hasMaterial  ontology#hasMint  \
# 0                   struck                   ae            siscia
# 1                   struck                   av              rome
# 2                   struck                   ae           treveri
# 3                   struck                   av          aquileia
# 4                   struck                   ar              rome
# 5                   struck                   av           arelate
# 6                   struck                   ae              rome
# 7                   struck                   ar   uncertain_value
# 8                   struck                   av  antiocheia_syria
# 9                   struck                   ar              rome
# 10                  struck                   ae    constantinople
# 11                  struck                                   rome
# 12                  struck                   ae              rome
# 13                  struck                   ar          lugdunum
# 14                  struck                   ae          aquileia
# 15                  struck                   ae              rome
# 16                  struck                   ae           treveri
# 17                  struck                   ae              rome
# 18                  struck                   ar              rome
# 19                  struck                   ae           treveri
#
#                       @id_obverse ontology#hasRegion  ... ontology#hasIssuer  \
# 0           ric.6.sis.221#obverse           pannonia  ...
# 1          ric.4.ph_i.28A#obverse              italy  ...
# 2         ric.9.tri.96B.2#obverse             gallia  ...
# 3              ric.8.aq.3#obverse              italy  ...
# 4           ric.4.crl.191#obverse              italy  ...
# 5              ric.7.ar.2#obverse             gallia  ...
# 6      ric.2_1(2).tit.288#obverse              italy  ...
# 7          ric.5.cara.745#obverse          britannia  ...
# 8          ric.6.anch.128#obverse              syria  ...
# 9            ric.5.aur.45#obverse              italy  ...
# 10          ric.9.cnp.57B#obverse             thrace  ...
# 11          ric.4.pert.1A#obverse              italy  ...
# 12          ric.7.rom.352#obverse              italy  ...
# 13           ric.5.pro.29#obverse             gallia  ...
# 14         ric.9.aq.7A.xb#obverse              italy  ...
# 15    ric.2_3(2).hdn.2680#obverse              italy  ...
# 16          ric.7.tri.205#obverse             gallia  ...
# 17       ric.3.m_aur.1397#obverse              italy  ...
# 18  ric.2.tr.730_denarius#obverse              italy  ...
# 19          ric.7.tri.175#obverse             gallia  ...
#
#                  ontology#hasLegend_obverse ontology#hasPortrait_obverse  \
# 0                    DIVO GAL VAL MAXIMIANO                     galerius
# 1                   IMP M IVL PHILIPPVS AVG              philip_the_arab
# 2                   D N THEODO-SIVS P F AVG                 theodosius_i
# 3                  FL IVL CONS-TANS P F AVG                     constans
# 4                   ANTONINVS PIVS AVG BRIT                    caracalla
# 5                         LICINI-VS P F AVG                     licinius
# 6   CAES DIVI AVG VESP F DOMITIANVS COS VII                     domitian
# 7                              IMP CARAVSIV                    carausius
# 8                       MAXIMIANVS AVGVSTVS                     galerius
# 9                        IMP AVRELIANVS AVG                     aurelian
# 10                   D N GRATIA-NVS P F AVG                      gratian
# 11               IMP CAES P HELV PERTIN AVG                     pertinax
# 12                 FL IVL CONSTANTIVS NOB C               constantius_ii
# 13                     IMP C PROBVS P F AVG                       probus
# 14               D N VALENTINI-ANVS P F AVG                valentinian_i
# 15                          L AELIVS CAESAR                lucius_aelius
# 16                   DIVO MAXIMIANO OPT IMP                     maximian
# 17             L AVREL VERVS AVG ARMENIACVS                  nomisma.rdf
# 18                  PLOTINA AVG IMP TRAIANI                      plotina
# 19                  FL IVL CRISPVS NOB CAES                      crispus
#
#                                   description_obverse  \
# 0                     Head of Galerius, veiled, right
# 1   Bust of Philip the Arab, laureate, draped, cui...
# 2   Bust of Theodosius I, pearl-diademed, draped a...
# 3   Bust of Constans, laureate, rosette-diademed, ...
# 4                  Head of Caracalla, laureate, right
# 5                   Head of Licinius, laureate, right
# 6                   Head of Domitian, laureate, right
# 7           Bust of Carausius, radiate, draped, right
# 8                   Head of Galerius, laureate, right
# 9         Bust of Aurelian, radiate, cuirassed, right
# 10  Bust of Gratian, rosette-diademed, draped and ...
# 11                  Head of Pertinax, laureate, right
# 12  Bust of Constantius II, laureate, draped, cuir...
# 13          Bust of Probus, radiate, cuirassed, right
# 14  Bust of Valentinian I, pearl-diademed, draped,...
# 15                Head of Lucius Aelius Caesar, right
# 16          Head of Maximian, veiled, laureate, right
# 17              Head of Lucius Verus, laureate, right
# 18      Bust of Plotina, draped, right; hair in queue
# 19  Bust of Crispus, laureate, draped, cuirassed, ...
#
#        ontology#hasLegend_reverse         ontology#hasPortrait_reverse  \
# 0                 FORTI FOR-TVNAE                                58260
# 1                     ANNONA AVGG                          nomisma.rdf
# 2               GLORIA RO-MANORVM
# 3         VIRTVS - CONSTANTIS AVG                             constans
# 4       PONTIF TR P XIIII COS III                                80685
# 5      PRINCIPIS PRO-VIDENTISSIMI
# 6                  PAX AVGVST S C                                76227
# 7                       COMES AVG                                57060
# 8        CONSVL VIII - P P PROCOS                             galerius
# 9                   AEQVITAS AVGG                                85985
# 10               CONCOR-DIA AVGGG  _:Nbe85fc321e1b40e29775814a80416d5d
# 11         AEQVIT AVG TR P COS II                                85985
# 12             GLOR-IA EXERC-ITVS
# 13                  FIDES MILITVM                                69305
# 14              GLORIA RO-MANORVM
# 15                 S C (in field)                                58668
# 16              REQVIES OPT • MER                             maximian
# 17    TR P IIII IMP II COS II S C                                60915
# 18  CAES AVG GERMA DAC COS VI P P                                60911
# 19           CLARITAS REIPVBLICAE                                58616
#
#                                   description_reverse  \
# 0   Fortuna, draped, standing left by wheel, holdi...
# 1   Annona, draped, standing left, holding corn-ea...
# 2   Emperor advancing right, dragging captive with...
# 3   Constans, draped, cuirassed, standing front, h...
# 4   Virtus, helmeted, draped, standing right, left...
# 5   TIA; on ground to left, helmet; on ground to r...
# 6   Pax standing left, holding branch and cornucopiae
# 7   Minerva, helmeted, draped, standing left, hold...
# 8   Galerius, laureate, togate, standing front, he...
# 9   Aequitas, draped, standing right, holding scal...
# 10  ?Constantinopolis, helmeted, head left, seated...
# 11  Aequitas, draped, standing left, holding scale...
# 12  Two soldiers, helmeted, draped, cuirassed, sta...
# 13  Fides, draped, standing left, holding ensign i...
# 14  Emperor advancing right, dragging captive with...
# 15  Salus seated left, holding patera and with elb...
# 16  Maximian, veiled, draped, seated left in curul...
# 17  Victory, winged, half-draped, standing right, ...
# 18  Vesta seated left on curule chair, holding pal...
# 19  Sol, radiate, chlamys draped across left shoul...
#
#    ontology#hasControlmark_reverse not_before not_after
# 0                             None      311.0     311.0
# 1                             None      244.0     247.0
# 2                             None      388.0     392.0
# 3                             None      337.0     340.0
# 4                             None      211.0     211.0
# 5                             None      313.0     313.0
# 6                             None       80.0      81.0
# 7                             None      286.0     293.0
# 8                             None      310.0     311.0
# 9                             None      270.0     275.0
# 10                            None      378.0     383.0
# 11                            None      193.0     193.0
# 12                            None      333.0     335.0
# 13                            None      276.0     282.0
# 14                            None      364.0     367.0
# 15                            None      137.0     137.0
# 16                            None      318.0     318.0
# 17                            None      163.0     164.0
# 18                            None       98.0     117.0
# 19                            None      317.0     318.0
#
# [20 rows x 31 columns]

# %%
coins.to_parquet("../data/coins_df.parquet")
